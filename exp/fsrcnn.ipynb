# %%
import sys
import os

# Gán đường dẫn tuyệt đối của thư mục GỐC dự án (chứa thư mục 'src')
project_root = 'D:/Github_Local_path/FIRE' 

# Thêm đường dẫn gốc vào Python Path
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"Đã thêm thư mục gốc vào Python Path: {project_root}")
# Out:
# Đã thêm thư mục gốc vào Python Path: D:/Github_Local_path/FIRE

# %%
# !pip install hydra-core

# %%
# %pip install torchmetrics

from src.eval.default import DefaultEvaluator
# %run D:/Github_Local_path/FIRE/main.py \
    loader.scale=2 \
    loader.hr_dir=D:/Github_Local_path/FIRE/data \
    loader.augment=[] \
    model=fsrcnn \
    trainer.epochs=50 \
    eval.n_samples_show=0 \
    loader.num_workers=0
# Out:
# ...
#    ---------------------------------------- 0.0/983.2 kB ? eta -:--:--
#    --------------------- ------------------ 524.3/983.2 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 983.2/983.2 kB 5.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [lightning-utilities]
#    ---------------------------------------- 0/2 [lightning-utilities]
#    ---------------------------------------- 0/2 [lightning-utilities]
#    ---------------------------------------- 0/2 [lightning-utilities]
#    -------------------- ------------------- 1/2 [torchmetrics]
#    -------------------- ------------------- 1/2 [torchmetrics]
#    -------------------- ------------------- 1/2 [torchmetrics]
#    -------------------- ------------------- 1/2 [torchmetrics]
#    -------------------- ------------------- 1/2 [torchmetrics]
#    -------------------- ------------------- 1/2 [torchmetrics]
#    -------------------- ------------------- 1/2 [torchmetrics]
# ...
